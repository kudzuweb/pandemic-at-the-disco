# %%
import pandas as pd

# %%
#import full Billboard csv
dupes = pd.read_csv(r"../data/cleanBillboard1920.csv")
dupes
# Out:
#              date                                         track  \
# 0      2019-01-05                                 Thank U  Next
# 1      2019-01-05                                    Without Me
# 2      2019-01-05               All I Want For Christmas Is You
# 3      2019-01-05                                    Sicko Mode
# 4      2019-01-05  Sunflower  Spider-Man  Into The Spider-Verse
# ...           ...                                           ...
# 10395  2020-12-26                                     Good Time
# 10396  2020-12-26                          Throat Baby  Go Baby
# 10397  2020-12-26                                       Errbody
# 10398  2020-12-26                         Favorite Time Of Year
# 10399  2020-12-26                                Beautiful Trip
#
#                        artist
# 0               Ariana Grande
# 1                      Halsey
# 2                Mariah Carey
# 3                Travis Scott
# 4      Post Malone   Swae Lee
# ...

# %%
#import masterframe csv
mf = pd.read_csv(r"../data/masterframe.csv")
mf
# Out:
#             date                                         track  \
# 0     2019-01-05                                 Thank U  Next
# 1     2019-01-05                                    Without Me
# 2     2019-01-05               All I Want For Christmas Is You
# 3     2019-01-05                                    Sicko Mode
# 4     2019-01-05  Sunflower  Spider-Man  Into The Spider-Verse
# ...          ...                                           ...
# 1310  2020-12-26                               Heaven On Earth
# 1311  2020-12-26                             Reminds Me Of You
# 1312  2020-12-26                                    Sad People
# 1313  2020-12-26                                       Damaged
# 1314  2020-12-26                                Beautiful Trip
#
#                           artist  danceability  energy   key  loudness  mode  \
# 0                  Ariana Grande         0.717   0.653   1.0    -5.634   1.0
# ...

# %%
#many-to-one merge

fullmaster = pd.merge(dupes, mf[['track', 'artist', 'danceability', 'energy', 'key', 'loudness', 'mode', 'speechiness', 'acousticness', 'instrumentalness', 'liveness', 'valence', 'tempo', 'id', 'duration_ms', 'time_signature', 'error']], on=['track', 'artist'], how= 'left')
fullmaster
# Out:
#              date                                         track  \
# 0      2019-01-05                                 Thank U  Next
# 1      2019-01-05                                    Without Me
# 2      2019-01-05               All I Want For Christmas Is You
# 3      2019-01-05                                    Sicko Mode
# 4      2019-01-05  Sunflower  Spider-Man  Into The Spider-Verse
# ...           ...                                           ...
# 10395  2020-12-26                                     Good Time
# 10396  2020-12-26                          Throat Baby  Go Baby
# 10397  2020-12-26                                       Errbody
# 10398  2020-12-26                         Favorite Time Of Year
# 10399  2020-12-26                                Beautiful Trip
#
#                        artist  danceability  energy   key  loudness  mode  \
# 0               Ariana Grande         0.717   0.653   1.0    -5.634   1.0
# ...

# %%
#export fullmaster csv
fullmaster.to_csv('../data/fullmaster.csv', index= False)
